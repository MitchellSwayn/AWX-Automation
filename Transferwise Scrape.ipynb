# %%
import pandas as pd
import numpy as np
import time

# %%
url = ["https://wise.com/gb/pricing/send-money?source=EUR&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=EUR&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=GBP&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=INR&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=USD&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AED&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=AUD&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BGN&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=BRL&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CAD&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CHF&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=CZK&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=DKK&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HKD&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HRK&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=HUF&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=IDR&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=JPY&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=MYR&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NOK&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=NZD&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=PLN&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=RON&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SEK&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=SGD&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=EUR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=EUR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=EUR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=GBP&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=GBP&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=GBP&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=INR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=INR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=INR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=USD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=USD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=USD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=AED&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=AED&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=AED&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=AUD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=AUD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=AUD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=BGN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=BGN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=BGN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=BRL&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=BRL&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=BRL&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CAD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CAD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CAD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CHF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CHF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CHF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CZK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CZK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=CZK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=DKK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=DKK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=DKK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HKD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HKD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HKD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HRK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HRK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HRK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HUF&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HUF&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=HUF&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=IDR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=IDR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=IDR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=JPY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=JPY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=JPY&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=MYR&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=MYR&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=MYR&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=NOK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=NOK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=NOK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=NZD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=NZD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=NZD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=PLN&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=PLN&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=PLN&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=RON&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=RON&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=RON&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=SEK&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=SEK&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=SEK&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=SGD&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=SGD&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=SGD&payInMethod=BANK_TRANSFER&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=TRY&payInMethod=VISA_DEBIT_OR_PREPAID&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=TRY&payInMethod=SWIFT&targetAmount=1000",
"https://wise.com/gb/pricing/send-money?source=TRY&target=TRY&payInMethod=BANK_TRANSFER&targetAmount=1000"]

# %%
from selenium import webdriver
PATH = "./chromedriver"
driver = webdriver.Chrome(PATH)

# %%
#data = pd.DataFrame(columns = ['url', 'loaded_url', "source", "target", "method", 'fixed', "varaible", "match"])

# %%
for i in url[270:]:
    driver.get(i)
    time.sleep(1.5)
    url = i
    
    loaded_url = driver.current_url
    try:
        source = loaded_url.split('=')[1].split('&')[0]
        target = loaded_url.split('=')[2].split('&')[0]
        method = loaded_url.split('=')[3].split('&')[0]
    except:
        source = "Fail"
        target = "Fail"
        method = "Fail"
    
    fixed = driver.find_elements_by_class_name('fee-digits')[0].text.split(" ")[0]
    variable = driver.find_elements_by_class_name('fee-digits')[2].text.replace("(","").replace(")","")
    to_append = pd.Series([url, loaded_url, source, target, method, fixed, variable, "test"], index = data.columns)
    data = data.append(to_append, ignore_index=True)

# %%
data
# Out:
#                                                    url  \
# 0    https://wise.com/gb/pricing/send-money?source=...
# 1    https://wise.com/gb/pricing/send-money?source=...
# 2    https://wise.com/gb/pricing/send-money?source=...
# 3    https://wise.com/gb/pricing/send-money?source=...
# 4    https://wise.com/gb/pricing/send-money?source=...
# ..                                                 ...
# 304  https://wise.com/gb/pricing/send-money?source=...
# 305  https://wise.com/gb/pricing/send-money?source=...
# 306  https://wise.com/gb/pricing/send-money?source=...
# 307  https://wise.com/gb/pricing/send-money?source=...
# 308  https://wise.com/gb/pricing/send-money?source=...
#
#                                             loaded_url source target  \
# 0    https://wise.com/gb/pricing/send-money?source=...    EUR    EUR
# 1    https://wise.com/gb/pricing/send-money?source=...    EUR    EUR
# 2    https://wise.com/gb/pricing/send-money?source=...    EUR    EUR
# ...

# %%
data.to_csv('./data.csv', index=False)
